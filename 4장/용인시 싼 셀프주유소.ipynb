# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome(r'C:\Users\user\Desktop\사용파일\데이터분석\데이터 분석\chromedriver_win32 (2)\chromedriver')
driver.get("https://www.opinet.co.kr/searRgSelect.do")
driver.get("https://www.opinet.co.kr/searRgSelect.do") # 두번 작성하면됨
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7204\1854152714.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\user\Desktop\사용파일\데이터분석\데이터 분석\chromedriver_win32 (2)\chromedriver')

# %%
gu_list_raw = driver.find_element_by_xpath('//*[@id="SIGUNGU_NM0"]')
gu_list = gu_list_raw.find_elements_by_tag_name("option")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7204\2591580309.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   gu_list_raw = driver.find_element_by_xpath('//*[@id="SIGUNGU_NM0"]')
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webelement.py:359: UserWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   warnings.warn("find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead")

# %%
gu_names = [option.get_attribute('value') for option in gu_list]
gu_names.remove('')
gu_names
# Out:
# ['가평군',
#  '고양시',
#  '고양시덕양구',
#  '고양시일산동구',
#  '고양시일산서구',
#  '과천시',
#  '광명시',
#  '광주시',
#  '구리시',
#  '군포시',
#  '김포시',
#  '남양주시',
#  '동두천시',
#  '부천시',
#  '성남시',
#  '성남시분당구',
#  '성남시수정구',
#  '성남시중원구',
#  '수원시',
#  '수원시권선구',
#  '수원시영통구',
#  '수원시장안구',
#  '수원시팔달구',
#  '시흥시',
#  '안산시',
#  '안산시단원구',
#  '안산시상록구',
#  '안성시',
#  '안양시',
#  '안양시동안구',
#  '안양시만안구',
#  '양주시',
#  '양평군',
#  '여주시',
#  '연천군',
#  '오산시',
#  '용인시',
#  '용인시기흥구',
#  '용인시수지구',
#  '용인시처인구',
#  '의왕시',
#  '의정부시',
#  '이천시',
#  '파주시',
#  '평택시',
#  '포천시',
#  '하남시',
#  '화성시']

# %%
import time
from tqdm import tqdm_notebook

for gu in tqdm_notebook(gu_names):
    element = driver.find_element_by_id("SIGUNGU_NM0")
    element.send_keys(gu)
    
    time.sleep(2)
    
    xpath = """//*[@id="searRgSelect"]"""
    element_sel_gu = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)
    
    xpath = """//*[@id="glopopd_excel"]"""
    element_get_excel = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7204\3213897217.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for gu in tqdm_notebook(gu_names):
#   0%|          | 0/48 [00:00<?, ?it/s]
# C:\Users\user\AppData\Local\Temp\ipykernel_7204\3213897217.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element = driver.find_element_by_id("SIGUNGU_NM0")
# C:\Users\user\AppData\Local\Temp\ipykernel_7204\3213897217.py:11: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   element_sel_gu = driver.find_element_by_xpath(xpath).click()
# C:\Users\user\AppData\Local\Temp\ipykernel_7204\3213897217.py:16: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   element_get_excel = driver.find_element_by_xpath(xpath).click()

# %%
import pandas as pd
from glob import glob

# %%
glob('./data/경기/*xls')
# Out:
# ['./data/경기\\지역_위치별(주유소) (1).xls',
#  './data/경기\\지역_위치별(주유소) (10).xls',
#  './data/경기\\지역_위치별(주유소) (11).xls',
#  './data/경기\\지역_위치별(주유소) (12).xls',
#  './data/경기\\지역_위치별(주유소) (13).xls',
#  './data/경기\\지역_위치별(주유소) (14).xls',
#  './data/경기\\지역_위치별(주유소) (15).xls',
#  './data/경기\\지역_위치별(주유소) (16).xls',
#  './data/경기\\지역_위치별(주유소) (17).xls',
#  './data/경기\\지역_위치별(주유소) (18).xls',
#  './data/경기\\지역_위치별(주유소) (19).xls',
#  './data/경기\\지역_위치별(주유소) (2).xls',
#  './data/경기\\지역_위치별(주유소) (20).xls',
#  './data/경기\\지역_위치별(주유소) (21).xls',
#  './data/경기\\지역_위치별(주유소) (22).xls',
#  './data/경기\\지역_위치별(주유소) (23).xls',
#  './data/경기\\지역_위치별(주유소) (24).xls',
#  './data/경기\\지역_위치별(주유소) (25).xls',
#  './data/경기\\지역_위치별(주유소) (26).xls',
#  './data/경기\\지역_위치별(주유소) (27).xls',
#  './data/경기\\지역_위치별(주유소) (28).xls',
#  './data/경기\\지역_위치별(주유소) (29).xls',
#  './data/경기\\지역_위치별(주유소) (3).xls',
#  './data/경기\\지역_위치별(주유소) (30).xls',
#  './data/경기\\지역_위치별(주유소) (31).xls',
#  './data/경기\\지역_위치별(주유소) (32).xls',
# ...

# %%
stations_files = glob('./data/경기/*xls')
stations_files
# Out:
# ['./data/경기\\지역_위치별(주유소) (1).xls',
#  './data/경기\\지역_위치별(주유소) (10).xls',
#  './data/경기\\지역_위치별(주유소) (11).xls',
#  './data/경기\\지역_위치별(주유소) (12).xls',
#  './data/경기\\지역_위치별(주유소) (13).xls',
#  './data/경기\\지역_위치별(주유소) (14).xls',
#  './data/경기\\지역_위치별(주유소) (15).xls',
#  './data/경기\\지역_위치별(주유소) (16).xls',
#  './data/경기\\지역_위치별(주유소) (17).xls',
#  './data/경기\\지역_위치별(주유소) (18).xls',
#  './data/경기\\지역_위치별(주유소) (19).xls',
#  './data/경기\\지역_위치별(주유소) (2).xls',
#  './data/경기\\지역_위치별(주유소) (20).xls',
#  './data/경기\\지역_위치별(주유소) (21).xls',
#  './data/경기\\지역_위치별(주유소) (22).xls',
#  './data/경기\\지역_위치별(주유소) (23).xls',
#  './data/경기\\지역_위치별(주유소) (24).xls',
#  './data/경기\\지역_위치별(주유소) (25).xls',
#  './data/경기\\지역_위치별(주유소) (26).xls',
#  './data/경기\\지역_위치별(주유소) (27).xls',
#  './data/경기\\지역_위치별(주유소) (28).xls',
#  './data/경기\\지역_위치별(주유소) (29).xls',
#  './data/경기\\지역_위치별(주유소) (3).xls',
#  './data/경기\\지역_위치별(주유소) (30).xls',
#  './data/경기\\지역_위치별(주유소) (31).xls',
#  './data/경기\\지역_위치별(주유소) (32).xls',
# ...

# %%
tmp_raw = []

for file_name in stations_files:
    tmp = pd.read_excel(file_name, header=2)
    tmp_raw.append(tmp)
    
station_raw = pd.concat(tmp_raw) # xlrd가 뭐지

# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2955 entries, 0 to 42
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      2955 non-null   object
#  1   상호      2955 non-null   object
#  2   주소      2955 non-null   object
#  3   상표      2955 non-null   object
#  4   전화번호    2955 non-null   object
#  5   셀프여부    2955 non-null   object
#  6   고급휘발유   2955 non-null   object
#  7   휘발유     2955 non-null   object
#  8   경유      2955 non-null   object
#  9   실내등유    2955 non-null   object
# dtypes: object(10)
# memory usage: 253.9+ KB

# %%
station_raw
# Out:
#      지역            상호                         주소      상표          전화번호 셀프여부  \
# 0   경기도    (주)내유셀프주유소        경기 고양시 덕양구 통일로 1228  현대오일뱅크  031-963-2463    Y
# 1   경기도  세일석유㈜ 통일로 일품   경기 고양시 덕양구 통일로 862 (관산동)   S-OIL  031-962-8055    Y
# 2   경기도        개나리주유소   경기 고양시 덕양구 보광로 126 (벽제동)   알뜰주유소  031-962-5545    Y
# 3   경기도        동원2주유소  경기 고양시 덕양구 통일로 1180 (내유동)   GS칼텍스  031-969-5148    Y
# 4   경기도         한솔주유소        경기 고양시 덕양구 통일로 1015   GS칼텍스  031-962-5182    Y
# ..  ...           ...                        ...     ...           ...  ...
# 38  경기도   청평하나오일뱅크주유소        경기 가평군 청평면 경춘로 1232  현대오일뱅크  031-585-1705    N
# 39  경기도   가평(서울방향)주유소        경기 가평군 설악면 미사리로 544   SK에너지  031-584-5159    N
# 40  경기도       국토셀프주유소        경기 가평군 조종면 비득재길 120   SK에너지  031-585-6786    Y
# 41  경기도         가평주유소       경기 가평군 가평읍 가화로 41-16   S-OIL  031-582-3114    N
# 42  경기도       가평설악주유소        경기 가평군 설악면 신천중앙로 30   SK에너지  031-585-5140    N
#
#    고급휘발유   휘발유    경유  실내등유
# 0      -  1923  1845     -
# ...

# %%
stations = pd.DataFrame({'Oil_store':station_raw['상호'], 
                                       '주소':station_raw['주소'],
                                       '가격':station_raw['휘발유'],
                                       '셀프':station_raw['셀프여부'],
                                       '상표':station_raw['상표']  })
stations.head()
# Out:
#       Oil_store                         주소    가격 셀프      상표
# 0    (주)내유셀프주유소        경기 고양시 덕양구 통일로 1228  1923  Y  현대오일뱅크
# 1  세일석유㈜ 통일로 일품   경기 고양시 덕양구 통일로 862 (관산동)  1925  Y   S-OIL
# 2        개나리주유소   경기 고양시 덕양구 보광로 126 (벽제동)  1925  Y   알뜰주유소
# 3        동원2주유소  경기 고양시 덕양구 통일로 1180 (내유동)  1934  Y   GS칼텍스
# 4         한솔주유소        경기 고양시 덕양구 통일로 1015  1934  Y   GS칼텍스

# %%
len(stations.loc[:])
# Out:
# 2955

# %%
stations.head(145)# 길이가 229까지 인듯
# Out:
#           Oil_store                         주소    가격 셀프      상표     구
# 0        (주)내유셀프주유소        경기 고양시 덕양구 통일로 1228  1923  Y  현대오일뱅크   덕양구
# 1      세일석유㈜ 통일로 일품   경기 고양시 덕양구 통일로 862 (관산동)  1925  Y   S-OIL   덕양구
# 2            개나리주유소   경기 고양시 덕양구 보광로 126 (벽제동)  1925  Y   알뜰주유소   덕양구
# 3            동원2주유소  경기 고양시 덕양구 통일로 1180 (내유동)  1934  Y   GS칼텍스   덕양구
# 4             한솔주유소        경기 고양시 덕양구 통일로 1015  1934  Y   GS칼텍스   덕양구
# ..              ...                        ...   ... ..     ...   ...
# 140     (주)원흥 원당동지점        경기 고양시 덕양구 호국로 1113     -  Y  현대오일뱅크   덕양구
# 141           정미주유소  경기 고양시 덕양구 호국로 1827 (고양동)     -  N   GS칼텍스   덕양구
# 142           백송주유소  경기 고양시 일산서구 덕이로 188 (덕이동)     -  Y    자가상표  일산서구
# 0    신김포농협대곶지점셀프주유소          경기 김포시 대곶면 율생로 99  1887  Y  NH-OIL   대곶면
# 1             화곡주유소        경기 김포시 대곶면 대곶북로 347  1936  Y   알뜰주유소   대곶면
#
# [145 rows x 6 columns]

# %%
for station
y_stations = stations.loc[0][0:1]
y_stations.concat(stations.loc[0][1:2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [47], in <cell line: 2>()
#       1 y_stations = stations.loc[0][0:1]
# ----> 2 y_stations.concat(stations.loc[0][1:2])
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
type(y_stations)
# Out:
# pandas.core.frame.DataFrame

# %%
str(stations.loc[0][0:1]['주소']).split()
stations.loc[0][0:1]['주소']
# Out:
# 0    경기 고양시 덕양구 통일로 1228
# Name: 주소, dtype: object

# %%
y_stations = pd.concat([y_stations,stations.loc[0][1:2]])

# %%
y_stations
# Out:
#         Oil_store                 주소    가격 셀프      상표    구
# 0  신김포농협대곶지점셀프주유소  경기 김포시 대곶면 율생로 99  1887  Y  NH-OIL  대곶면

# %%
y_stations = pd.DataFrame()

# %%
try:
    for i in range(len(stations)):
        for j in range(len(stations.loc[i])):
            if str(stations.loc[i][j:j+1]['주소']).split()[2] == '용인시':
                y_stations = pd.concat([y_stations, stations.loc[i][j:j+1]])
except:
    pass

# %%
y_stations
# Out:
#              Oil_store                              주소    가격 셀프      상표    구
# 0        오일스타(주)경기남부지점      경기 용인시 처인구 중부대로 1653 (마평동)  1939  Y    자가상표  처인구
# 0              아이언맨주유소         경기 용인시 기흥구 신갈로 13 (상갈동)  1963  Y   알뜰주유소  기흥구
# 0    현대오일뱅크㈜직영 상현제일주유소       경기 용인시 수지구 포은대로 150 (상현동)  1990  N  현대오일뱅크  수지구
# 0        오일스타(주)경기남부지점      경기 용인시 처인구 중부대로 1653 (마평동)  1939  Y    자가상표  처인구
# 1             SK선봉대주유소              경기 용인시 처인구 성산로 153  1945  Y   SK에너지  처인구
# ..                 ...                             ...   ... ..     ...  ...
# 188              세명주유소              경기 용인시 기흥구 신정로 293  2137  N   GS칼텍스  기흥구
# 189     (주)남경석유 마북로주유소        경기 용인시 기흥구 마북로 130 (마북동)  2179  N   SK에너지  기흥구
# 190            신무궁화주유소  경기 용인시 기흥구 용구대로2469번길 78 (보정동)  2188  N  현대오일뱅크  기흥구
# 191         (주)도시공간에너지             경기 용인시 기흥구 중부대로 520     -  Y   GS칼텍스  기흥구
# 192          (주)153주유소         경기 용인시 기흥구 공세로 64 (고매동)     -  Y   SK에너지  기흥구
#
# [386 rows x 6 columns]

# %%
stations['구'] = [eachAddress.split()[2] for eachAddress in stations['주소']] # 경기 떄문에 3번째 때다가 붙힘
stations.head(20)
# Out:
#              Oil_store                          주소    가격 셀프      상표     구
# 0           (주)내유셀프주유소         경기 고양시 덕양구 통일로 1228  1923  Y  현대오일뱅크   덕양구
# 1         세일석유㈜ 통일로 일품    경기 고양시 덕양구 통일로 862 (관산동)  1925  Y   S-OIL   덕양구
# 2               개나리주유소    경기 고양시 덕양구 보광로 126 (벽제동)  1925  Y   알뜰주유소   덕양구
# 3               동원2주유소   경기 고양시 덕양구 통일로 1180 (내유동)  1934  Y   GS칼텍스   덕양구
# 4                한솔주유소         경기 고양시 덕양구 통일로 1015  1934  Y   GS칼텍스   덕양구
# 5       (주)삼표에너지 동해주유소  경기도 고양시 덕양구  중앙로 110 (화전동)  1935  Y   GS칼텍스   덕양구
# 6   (주)헨지스에너지직영 세이버주유소    경기 고양시 덕양구 화랑로 124 (화전동)  1940  N  현대오일뱅크   덕양구
# 7               중앙로주유소    경기 고양시 덕양구 중앙로 113 (화전동)  1940  Y   SK에너지   덕양구
# 8    정상에너지(주)강매self주유소    경기 고양시 덕양구 중앙로 316 (도내동)  1940  Y   SK에너지   덕양구
# 9                구산주유소         경기 고양시 일산서구 구산로 120  1944  N   SK에너지  일산서구
# 10               안곡주유소        경기 고양시 일산동구 고양대로 831  1945  Y  현대오일뱅크  일산동구
# 11         (주)원흥.벽제동지점         경기 고양시 덕양구 호국로 1664  1945  Y  현대오일뱅크   덕양구
# ...

# %%
y_stations['구'].unique()
# Out:
# array(['처인구', '기흥구', '수지구'], dtype=object)

# %%
y_stations[y_stations['가격']=='-']
# Out:
#       Oil_store                       주소 가격 셀프     상표    구
# 77    (주)153주유소  경기 용인시 기흥구 공세로 64 (고매동)  -  Y  SK에너지  기흥구
# 78   (주)도시공간에너지      경기 용인시 기흥구 중부대로 520  -  Y  GS칼텍스  기흥구
# 191  (주)도시공간에너지      경기 용인시 기흥구 중부대로 520  -  Y  GS칼텍스  기흥구
# 192   (주)153주유소  경기 용인시 기흥구 공세로 64 (고매동)  -  Y  SK에너지  기흥구

# %%
y_stations = y_stations[y_stations['가격'] != '-']
y_stations.head()
# Out:
#            Oil_store                          주소    가격 셀프      상표    구
# 0      오일스타(주)경기남부지점  경기 용인시 처인구 중부대로 1653 (마평동)  1939  Y    자가상표  처인구
# 0            아이언맨주유소     경기 용인시 기흥구 신갈로 13 (상갈동)  1963  Y   알뜰주유소  기흥구
# 0  현대오일뱅크㈜직영 상현제일주유소   경기 용인시 수지구 포은대로 150 (상현동)  1990  N  현대오일뱅크  수지구
# 0      오일스타(주)경기남부지점  경기 용인시 처인구 중부대로 1653 (마평동)  1939  Y    자가상표  처인구
# 1           SK선봉대주유소          경기 용인시 처인구 성산로 153  1945  Y   SK에너지  처인구

# %%
y_stations['가격'] = [float(value) for value in y_stations['가격']]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7204\422744532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_stations['가격'] = [float(value) for value in y_stations['가격']]

# %%
y_stations.reset_index(inplace=True)
del y_stations['index']

# %%
y_stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Oil_store  382 non-null    object
#  1   주소         382 non-null    object
#  2   가격         382 non-null    float64
#  3   셀프         382 non-null    object
#  4   상표         382 non-null    object
#  5   구          382 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 18.0+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
y_stations.boxplot(column='가격', by='셀프', figsize=(12,8));

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="상표", y="가격", hue="셀프", data=y_stations, palette="Set3")
plt.show() # 현대 오일 뱅크가 제일 싸고 NH-OIL은 셀프가 제일 싸다.

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="상표", y="가격", data=y_stations, palette="Set3")
sns.swarmplot(x="상표", y="가격", data=y_stations, color=".6")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 전체적을 알뜰 주유소 빼면 현대 오일뱅크가 제일 싼편

# %%
# 구별 주유 가격 확인하기

# %%
import json
import folium
import googlemaps
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
y_stations.sort_values(by='가격', ascending=False).head()
# Out:
#           Oil_store                              주소      가격 셀프      상표    구
# 381         신무궁화주유소  경기 용인시 기흥구 용구대로2469번길 78 (보정동)  2188.0  N  현대오일뱅크  기흥구
# 243         신무궁화주유소  경기 용인시 기흥구 용구대로2469번길 78 (보정동)  2188.0  N  현대오일뱅크  기흥구
# 380  (주)남경석유 마북로주유소        경기 용인시 기흥구 마북로 130 (마북동)  2179.0  N   SK에너지  기흥구
# 240  (주)남경석유 마북로주유소        경기 용인시 기흥구 마북로 130 (마북동)  2179.0  N   SK에너지  기흥구
# 379           세명주유소              경기 용인시 기흥구 신정로 293  2137.0  N   GS칼텍스  기흥구

# %%
y_stations.sort_values(by='가격', ascending=True).head()
# Out:
#        Oil_store                          주소      가격 셀프     상표    구
# 0  오일스타(주)경기남부지점  경기 용인시 처인구 중부대로 1653 (마평동)  1939.0  Y   자가상표  처인구
# 3  오일스타(주)경기남부지점  경기 용인시 처인구 중부대로 1653 (마평동)  1939.0  Y   자가상표  처인구
# 4       SK선봉대주유소          경기 용인시 처인구 성산로 153  1945.0  Y  SK에너지  처인구
# 7       SK선봉대주유소          경기 용인시 처인구 성산로 153  1945.0  Y  SK에너지  처인구
# 1        아이언맨주유소     경기 용인시 기흥구 신갈로 13 (상갈동)  1963.0  Y  알뜰주유소  기흥구

# %%
import numpy as np

gu_data = pd.pivot_table(y_stations, index=["구"], values=["가격"], 
                         aggfunc=np.mean)
gu_data.head()
# Out:
#               가격
# 구
# 기흥구  2018.000000
# 수지구  2025.857143
# 처인구  2011.610000

# %%
geo_path = r'C:\Users\user\Desktop\사용파일\데이터분석\데이터 분석\DATA\파이썬으로 데이터 주물럭\DataScience-master\data\02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5, 
                 tiles='Stamen Toner')

map.choropleth(geo_data = geo_str,
               data = gu_data,
               columns=[gu_data.index, '가격'],
               fill_color='PuRd', #PuRd, YlGnBu
               key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 주유 가격 상하위 10개 주유소 지도에 표기하기

# %%
oil_price_top10 = y_stations.sort_values(by='가격', ascending=False).head(10)
oil_price_top10
# Out:
#           Oil_store                              주소      가격 셀프      상표    구
# 381         신무궁화주유소  경기 용인시 기흥구 용구대로2469번길 78 (보정동)  2188.0  N  현대오일뱅크  기흥구
# 243         신무궁화주유소  경기 용인시 기흥구 용구대로2469번길 78 (보정동)  2188.0  N  현대오일뱅크  기흥구
# 380  (주)남경석유 마북로주유소        경기 용인시 기흥구 마북로 130 (마북동)  2179.0  N   SK에너지  기흥구
# 240  (주)남경석유 마북로주유소        경기 용인시 기흥구 마북로 130 (마북동)  2179.0  N   SK에너지  기흥구
# 379           세명주유소              경기 용인시 기흥구 신정로 293  2137.0  N   GS칼텍스  기흥구
# 237           세명주유소              경기 용인시 기흥구 신정로 293  2137.0  N   GS칼텍스  기흥구
# 234         동백시티주유소  경기 용인시 기흥구 동백죽전대로556번길 1 (동백동)  2119.0  N   SK에너지  기흥구
# 231           대호주유소       경기 용인시 기흥구 중부대로 202 (영덕동)  2119.0  N   GS칼텍스  기흥구
# 377           대호주유소       경기 용인시 기흥구 중부대로 202 (영덕동)  2119.0  N   GS칼텍스  기흥구
# 378         동백시티주유소  경기 용인시 기흥구 동백죽전대로556번길 1 (동백동)  2119.0  N   SK에너지  기흥구

# %%
oil_price_bottom10 = y_stations.sort_values(by='가격', ascending=True).head(10)
oil_price_bottom10
# Out:
#            Oil_store                              주소      가격 셀프     상표    구
# 0      오일스타(주)경기남부지점      경기 용인시 처인구 중부대로 1653 (마평동)  1939.0  Y   자가상표  처인구
# 3      오일스타(주)경기남부지점      경기 용인시 처인구 중부대로 1653 (마평동)  1939.0  Y   자가상표  처인구
# 4           SK선봉대주유소              경기 용인시 처인구 성산로 153  1945.0  Y  SK에너지  처인구
# 7           SK선봉대주유소              경기 용인시 처인구 성산로 153  1945.0  Y  SK에너지  처인구
# 1            아이언맨주유소         경기 용인시 기흥구 신갈로 13 (상갈동)  1963.0  Y  알뜰주유소  기흥구
# 8            아이언맨주유소         경기 용인시 기흥구 신갈로 13 (상갈동)  1963.0  Y  알뜰주유소  기흥구
# 5   SK에너지㈜직영 기쁨셀프주유소  경기 용인시 기흥구 용구대로2469번길130 (보정동)  1969.0  Y  SK에너지  기흥구
# 12  SK에너지㈜직영 기쁨셀프주유소  경기 용인시 기흥구 용구대로2469번길130 (보정동)  1969.0  Y  SK에너지  기흥구
# 16             미키주유소      경기 용인시 기흥구  용구대로 2469번길 57  1974.0  Y  알뜰주유소  기흥구
# 9              미키주유소      경기 용인시 기흥구  용구대로 2469번길 57  1974.0  Y  알뜰주유소  기흥구

# %%
gmap_key = "AIzaSyBtJSf6YU8BcQO0fLekEGixRQxgGG_iRzM" 
gmaps = googlemaps.Client(key=gmap_key)

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_top10.index):
    try:
        tmp_add = str(oil_price_top10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)

        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
        
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7204\3536952408.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n in tqdm_notebook(oil_price_top10.index):
#   0%|          | 0/10 [00:00<?, ?it/s]
#           Oil_store                              주소      가격 셀프      상표    구  \
# 381         신무궁화주유소  경기 용인시 기흥구 용구대로2469번길 78 (보정동)  2188.0  N  현대오일뱅크  기흥구
# 243         신무궁화주유소  경기 용인시 기흥구 용구대로2469번길 78 (보정동)  2188.0  N  현대오일뱅크  기흥구
# 380  (주)남경석유 마북로주유소        경기 용인시 기흥구 마북로 130 (마북동)  2179.0  N   SK에너지  기흥구
# 240  (주)남경석유 마북로주유소        경기 용인시 기흥구 마북로 130 (마북동)  2179.0  N   SK에너지  기흥구
# 379           세명주유소              경기 용인시 기흥구 신정로 293  2137.0  N   GS칼텍스  기흥구
# 237           세명주유소              경기 용인시 기흥구 신정로 293  2137.0  N   GS칼텍스  기흥구
# 234         동백시티주유소  경기 용인시 기흥구 동백죽전대로556번길 1 (동백동)  2119.0  N   SK에너지  기흥구
# 231           대호주유소       경기 용인시 기흥구 중부대로 202 (영덕동)  2119.0  N   GS칼텍스  기흥구
# ...

# %%
lat = []
lng = []

for n in tqdm_notebook(oil_price_bottom10.index):
    try:
        tmp_add = oil_price_bottom10['주소'][n].split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)

        tmp_loc = tmp_map[0]['geometry']
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
    
oil_price_bottom10['lat'] = lat
oil_price_bottom10['lng'] = lng
oil_price_bottom10
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7204\3540469356.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n in tqdm_notebook(oil_price_bottom10.index):
#   0%|          | 0/10 [00:00<?, ?it/s]
#            Oil_store                              주소      가격 셀프     상표    구  \
# 0      오일스타(주)경기남부지점      경기 용인시 처인구 중부대로 1653 (마평동)  1939.0  Y   자가상표  처인구
# 3      오일스타(주)경기남부지점      경기 용인시 처인구 중부대로 1653 (마평동)  1939.0  Y   자가상표  처인구
# 4           SK선봉대주유소              경기 용인시 처인구 성산로 153  1945.0  Y  SK에너지  처인구
# 7           SK선봉대주유소              경기 용인시 처인구 성산로 153  1945.0  Y  SK에너지  처인구
# 1            아이언맨주유소         경기 용인시 기흥구 신갈로 13 (상갈동)  1963.0  Y  알뜰주유소  기흥구
# 8            아이언맨주유소         경기 용인시 기흥구 신갈로 13 (상갈동)  1963.0  Y  알뜰주유소  기흥구
# 5   SK에너지㈜직영 기쁨셀프주유소  경기 용인시 기흥구 용구대로2469번길130 (보정동)  1969.0  Y  SK에너지  기흥구
# ...

# %%
map = folium.Map(location=[37.5202, 126.975], zoom_start=10.5)

for n in oil_price_top10.index:
    if pd.notnull(oil_price_top10['lat'][n]):
        folium.CircleMarker([oil_price_top10['lat'][n], oil_price_top10['lng'][n]], 
                                  radius=15, color='#CD3181', 
                                  fill_color='#CD3181',
                                  fill=True).add_to(map)
    
for n in oil_price_bottom10.index:
    if pd.notnull(oil_price_bottom10['lat'][n]): 
        folium.CircleMarker([oil_price_bottom10['lat'][n], 
                                  oil_price_bottom10['lng'][n]], 
                                  radius=15, color='#3186cc', 
                                  fill_color='#3186cc',
                                  fill=True).add_to(map)
        
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
